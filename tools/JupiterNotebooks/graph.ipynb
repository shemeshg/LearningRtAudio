# %% [markdown]
# # Run
#
# ````bash
# cd /Volumes/TEMP/developTestingTechnology/RtAudio/LearningRtAudio/tools/JupiterNotebooks
# /Volumes/TEMP/developTestingTechnology/RtAudio/LearningRtAudio/libs/TestRtAudio/build/main/main > g.txt
# ````

# %%
import pandas as pd
import datetime
import csv
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
headers = ['x',"y1","y2"]
df = pd.read_csv('/Volumes/TEMP/developTestingTechnology/RtAudio/LearningRtAudio/tools/JupiterNotebooks/g.txt',names=headers)
df
# Out:
#            x        y1        y2
# 0          0  0.000000  0.000000
# 1          1  0.038255  0.038255
# 2          2  0.076186  0.076186
# 3          3  0.113477  0.113477
# 4          4  0.149818  0.149818
# ...      ...       ...       ...
# 22045  22045 -0.280152 -0.280152
# 22046  22046 -0.290041 -0.290041
# 22047  22047 -0.300548 -0.300548
# 22048  22048 -0.311608 -0.311608
# 22049  22049 -0.323131 -0.323131
#
# [22050 rows x 3 columns]

# %%
df.head(2000).plot.line("x","y1")
# Out:
# <AxesSubplot:xlabel='x'>

# %%
from scipy.fft import fft, fftfreq
# Number of sample points
N = 1200 * 2
# sample spacing
T = 1.0 / (2000.0 * 2)
x = np.linspace(0.0, N*T, N, endpoint=False)
y = df["y1"].values 
yf = fft(y)
xf = fftfreq(N, T)[:N//2]
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()
